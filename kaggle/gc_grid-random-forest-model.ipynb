# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import copy

# %%
def standard_scalar_normalize(data_train, data_test): 
    scaler = StandardScaler()
    scaler.fit(data_train)
    normal_data_train = scaler.transform(data_train)
    normal_data_test = scaler.transform(data_test)
    return normal_data_train,normal_data_test

# %%
def data_processed():
    '''
    Used to read & normalize processed test and train data
    '''
    data_train=pd.read_csv("data/2022-02-07_LOANS_TRAIN.csv")
    data_test=pd.read_csv("data/2022-02-07_LOANS_TEST.csv")
    y_train=data_train['loan_status']
    data_train.drop(columns=['loan_status', 'id', 'issue_d_in_months', 'issue_d_year', 'zip_state_match', 
                               'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
                               'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
                               'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
                               'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA',
                               'WI', 'WV', 'WY'], inplace=True)
    
    data_test.drop(columns=['id', 'issue_d_in_months', 'issue_d_year', 'zip_state_match', 
                           'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
                           'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
                           'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
                           'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA',
                           'WI', 'WV', 'WY'], inplace=True)
    
    normal_data_train,normal_data_test=standard_scalar_normalize(data_train,data_test)
    return normal_data_train,normal_data_test,y_train

def AUC_score(y_ground_truth,y_predicted_probability):
    return roc_auc_score(y_ground_truth, y_predicted_probability)

def to_submission(ids, y_test_predicted_probability):
    y_test=pd.DataFrame(y_test_predicted_probability,columns=['loan_status'], index=ids)
    y_test.index.name = 'id'
    y_test.to_csv('data/submission.csv')
    return

# %%
X_train,X_test,Y_train=data_processed()
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, train_size=0.80, random_state=42)

# %%
parameters = {'n_estimators':  np.arange(100, 500, 100) , 'min_samples_leaf': np.arange(5, 71, 20), 'max_depth': np.arange(5, 30, 5)}
rfc = RandomForestClassifier(class_weight='balanced')
clf = GridSearchCV(rfc, parameters, scoring='roc_auc', verbose=2.1, n_jobs=1)
clf.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=100 ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=100, score=0.679, total=  13.7s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=100 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.8s remaining:    0.0s
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=100, score=0.688, total=  14.1s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=100 ...............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   27.9s remaining:    0.0s
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=100, score=0.681, total=  15.1s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=100 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=100, score=0.679, total=  14.0s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=100 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=100, score=0.682, total=  15.1s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=200 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=200, score=0.679, total=  29.8s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=200 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=200, score=0.688, total=  28.2s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=200 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=200, score=0.680, total=  27.0s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=200 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=200, score=0.679, total=  26.9s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=200 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=200, score=0.682, total=  26.7s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=300 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=300, score=0.680, total=  40.6s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=300 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=300, score=0.687, total=  40.2s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=300 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=300, score=0.681, total=  40.6s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=300 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=300, score=0.679, total=  40.7s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=300 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=300, score=0.681, total=  40.3s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=400 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=400, score=0.679, total=  53.8s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=400 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=400, score=0.688, total=  54.3s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=400 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=400, score=0.680, total=  54.2s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=400 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=400, score=0.679, total=  54.2s
# [CV] max_depth=5, min_samples_leaf=5, n_estimators=400 ...............
# [CV]  max_depth=5, min_samples_leaf=5, n_estimators=400, score=0.681, total=  53.5s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=100, score=0.680, total=  13.5s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=100, score=0.688, total=  13.2s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=100, score=0.680, total=  13.8s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=100, score=0.679, total=  13.4s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=100 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=100, score=0.681, total=  13.1s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=200, score=0.680, total=  27.2s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=200, score=0.688, total=  26.6s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=200, score=0.681, total=  27.0s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=200, score=0.680, total=  26.8s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=200 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=200, score=0.681, total=  27.2s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=300, score=0.679, total=  40.5s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=300, score=0.688, total=  40.0s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=300, score=0.681, total=  39.7s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=300, score=0.679, total=  41.0s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=300 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=300, score=0.682, total=  40.6s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=400, score=0.679, total=  54.2s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=400, score=0.688, total=  53.7s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=400, score=0.681, total=  53.8s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_leaf=25, n_estimators=400, score=0.679, total=  53.4s
# [CV] max_depth=5, min_samples_leaf=25, n_estimators=400 ..............
# [CV]  max_depth=5, min_samples_leaf

# [CV] max_depth=25, min_samples_leaf=65, n_estimators=300 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=300, score=0.687, total=  46.3s
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=300 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=300, score=0.695, total=  46.0s
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=300 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=300, score=0.689, total=  46.0s
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=300 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=300, score=0.686, total=  46.0s
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=300 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=300, score=0.689, total=  46.1s
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=400 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=400, score=0.687, total= 1.0min
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=400 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=400, score=0.695, total= 1.0min
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=400 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=400, score=0.689, total= 1.0min
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=400 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=400, score=0.686, total= 1.0min
# [CV] max_depth=25, min_samples_leaf=65, n_estimators=400 .............
# [CV]  max_depth=25, min_samples_leaf=65, n_estimators=400, score=0.689, total= 1.0min
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed: 250.3min finished
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced'),
#              n_jobs=1,
#              param_grid={'max_depth': array([ 5, 10, 15, 20, 25]),
#                          'min_samples_leaf': array([ 5, 25, 45, 65]),
#                          'n_estimators': array([100, 200, 300, 400])},
#              scoring='roc_auc', verbose=2.1)

# %%
clf.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_max_depth', 'param_min_samples_leaf', 'param_n_estimators', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
results_df = pd.DataFrame(clf.cv_results_)

# %%
clf.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_max_depth', 'param_min_samples_leaf', 'param_n_estimators', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
results_sub_df = results_df.loc[:, ['param_max_depth', 'param_min_samples_leaf', 'param_n_estimators', 'mean_test_score', 'std_test_score', 'rank_test_score']]
results_sub_df.sort_values('rank_test_score').head(20)
# Out:
#    param_max_depth param_min_samples_leaf param_n_estimators  mean_test_score  \
# 55              20                     25                400         0.690195
# 71              25                     25                400         0.690187
# 54              20                     25                300         0.689924
# 70              25                     25                300         0.689880
# 75              25                     45                400         0.689726
# 53              20                     25                200         0.689721
# 59              20                     45                400         0.689698
# 74              25                     45                300         0.689593
# 58              20                     45                300         0.689557
# 69              25                     25                200         0.689551
# 38              15                     25                300         0.689548
# 41              15                     45                200         0.689538
# 42              15                     45                300         0.689477
# 43              15                     45                400         0.689471
# 39              15                     25                400         0.689398
# 57              20                     45                200         0.689393
# 73              25                     45                200         0.689336
# 79              25                     65                400         0.689332
# 62              20                     65                300         0.689221
# 61              20                     65                200         0.689216
#
#     std_test_score  rank_test_score
# 55        0.003197                1
# 71        0.002948                2
# 54        0.003395                3
# 70        0.003388                4
# 75        0.003241                5
# 53        0.003178                6
# 59        0.003172                7
# 74        0.003261                8
# 58        0.003412                9
# 69        0.003313               10
# 38        0.003106               11
# 41        0.003549               12
# 42        0.003302               13
# 43        0.003221               14
# 39        0.003304               15
# 57        0.003664               16
# 73        0.003332               17
# 79        0.003209               18
# 62        0.003276               19
# 61        0.003156               20

# %%
Y_val_pred_prob=clf.best_estimator_.predict_proba(X_val)[:,1]
AUC_score(Y_val,Y_val_pred_prob)
# Out:
# 0.689535483443332

# %%
Y_train_pred_prob=clf.best_estimator_.predict_proba(X_train)[:,1]
AUC_score(Y_train,Y_train_pred_prob)
# Out:
# 0.8672438705361283

# %%
Y_val_pred=clf.best_estimator_.predict(X_val)
confusion_matrix(Y_val,Y_val_pred)
# Out:
# array([[25769,  7579],
#        [ 3229,  2873]])

# %%
Y_train_pred=clf.best_estimator_.predict(X_train)
confusion_matrix(Y_train,Y_train_pred)
# Out:
# array([[108347,  25331],
#        [  6314,  17808]])

# %%
clf.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 20,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 25,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 400,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Output for submissions - evaluate on test set

# %%
Y_test_pred_prob=clf.predict_proba(X_test)[:,1]

# %%
to_submission(pd.read_csv("data/2022-02-07_LOANS_TEST.csv")['id'], Y_test_pred_prob)
