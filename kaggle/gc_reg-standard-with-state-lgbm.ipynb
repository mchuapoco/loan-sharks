# %% [markdown]
# # Grid search LGBM with state one-hot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV


from sklearn.metrics import roc_auc_score,confusion_matrix
from sklearn.model_selection import train_test_split
import copy

# %%
def standard_scalar_normalize(data_train, data_test): 
    scaler = StandardScaler()
    scaler.fit(data_train)
    normal_data_train = scaler.transform(data_train)
    normal_data_test = scaler.transform(data_test)
    return normal_data_train,normal_data_test

# %%
def data_processed():
    '''
    Used to read & normalize processed test and train data
    '''
    data_train=pd.read_csv("data/2022-02-07_LOANS_TRAIN.csv")
    data_test=pd.read_csv("data/2022-02-07_LOANS_TEST.csv")
    y_train=data_train['loan_status']
    data_train.drop(columns=['loan_status', 'id', 'issue_d_in_months', 'issue_d_year', 'zip_state_match'], inplace=True)
    
    data_test.drop(columns=['id', 'issue_d_in_months', 'issue_d_year', 'zip_state_match'], inplace=True)
    
    normal_data_train,normal_data_test=standard_scalar_normalize(data_train,data_test)
    return normal_data_train,normal_data_test,y_train

def AUC_score(y_ground_truth,y_predicted_probability):
    return roc_auc_score(y_ground_truth, y_predicted_probability)

def to_submission(ids, y_test_predicted_probability):
    y_test=pd.DataFrame(y_test_predicted_probability,columns=['loan_status'], index=ids)
    y_test.index.name = 'id'
    y_test.to_csv('data/submission.csv')
    return

# %%
def classification_err(y, real_y):
    """
    This function returns the classification error between two equally-sized vectors of 
    labels; this is the fraction of samples for which the labels differ.
    
    Inputs:
        y: (N, ) shaped array of predicted labels
        real_y: (N, ) shaped array of true labels
    Output:
        Scalar classification error
    """

    return sum(y == real_y) / len(y)
    

def eval_tree_based_model_min_samples(clf, min_samples_leaf, X_train, y_train, X_test, y_test):
    """
    This function evaluates the given classifier (either a decision tree or random forest) at all of the 
    minimum leaf size parameters in the vector min_samples_leaf, using the given training and testing
    data. It returns two vector, with the training and testing classification errors.
    
    Inputs:
        clf: either a decision tree or random forest classifier object
        min_samples_leaf: a (T, ) vector of all the min_samples_leaf stopping condition parameters 
                            to test, where T is the number of parameters to test
        X_train: (N, D) matrix of training samples.
        y_train: (N, ) vector of training labels.
        X_test: (N, D) matrix of test samples
        y_test: (N, ) vector of test labels
    Output:
        train_err: (T, ) vector of classification errors on the training data
        test_err: (T, ) vector of classification errors on the test data
        train_auc: (T, ) vector of area under the ROC curve (AUC) on the training data
        test_auc: (T, ) vector of area under the ROC curve (AUC) on the testing data
    """
    
    train_err = []
    test_err = []
    train_auc = []
    test_auc = []
    for min_samp in min_samples_leaf: 
        print(min_samp)
        clf.min_child_samples = min_samp
        clf.fit(X_train, y_train, copy.deepcopy(y_train)*4 + 1)
        train_err.append(1 - clf.score(X_train, y_train))
        test_err.append(1 - clf.score(X_test, y_test))
        
        Y_train_pred_prob=clf.predict_proba(X_train)[:,1]
        train_auc.append(AUC_score(y_train,Y_train_pred_prob))
        
        Y_test_pred_prob=clf.predict_proba(X_test)[:,1]
        test_auc.append(AUC_score(y_test,Y_test_pred_prob))

    return train_err, test_err, train_auc, test_auc

# %%
def eval_tree_based_model_max_depth(clf, max_depth, X_train, y_train, X_test, y_test):
    """
    This function evaluates the given classifier (either a decision tree or random forest) at all of the 
    maximum tree depth parameters in the vector max_depth, using the given training and testing
    data. It returns two vector, with the training and testing classification errors.
    
    Inputs:
        clf: either a decision tree or random forest classifier object
        max_depth: a (T, ) vector of all the max_depth stopping condition parameters 
                            to test, where T is the number of parameters to test
        X_train: (N, D) matrix of training samples.
        y_train: (N, ) vector of training labels.
        X_test: (N, D) matrix of test samples
        y_test: (N, ) vector of test labels
    Output:
        train_err: (T, ) vector of classification errors on the training data
        test_err: (T, ) vector of classification errors on the test data
        train_auc: (T, ) vector of area under the ROC curve (AUC) on the training data
        test_auc: (T, ) vector of area under the ROC curve (AUC) on the testing data
    """
    train_err = []
    test_err = []
    train_auc = []
    test_auc = []
    for max_dep in max_depth: 
        print(max_dep)
        clf.max_depth = max_dep
        clf.fit(X_train, y_train, copy.deepcopy(y_train)*4 + 1)
        train_err.append(1 - clf.score(X_train, y_train))
        test_err.append(1 - clf.score(X_test, y_test))
        
        Y_train_pred_prob=clf.predict_proba(X_train)[:,1]
        train_auc.append(AUC_score(y_train,Y_train_pred_prob))
        
        Y_test_pred_prob=clf.predict_proba(X_test)[:,1]
        test_auc.append(AUC_score(y_test,Y_test_pred_prob))
        
    return train_err, test_err, train_auc, test_auc

# %%
def eval_tree_based_model_n_estimators(clf, n_estimators, X_train, y_train, X_test, y_test):
    """
    This function evaluates the given classifier (either a decision tree or random forest) at all of the 
    maximum tree depth parameters in the vector max_depth, using the given training and testing
    data. It returns two vector, with the training and testing classification errors.
    
    Inputs:
        clf: either a decision tree or random forest classifier object
        max_depth: a (T, ) vector of all the max_depth stopping condition parameters 
                            to test, where T is the number of parameters to test
        X_train: (N, D) matrix of training samples.
        y_train: (N, ) vector of training labels.
        X_test: (N, D) matrix of test samples
        y_test: (N, ) vector of test labels
    Output:
        train_err: (T, ) vector of classification errors on the training data
        test_err: (T, ) vector of classification errors on the test data
        train_auc: (T, ) vector of area under the ROC curve (AUC) on the training data
        test_auc: (T, ) vector of area under the ROC curve (AUC) on the testing data
    """
    train_err = []
    test_err = []
    train_auc = []
    test_auc = []
    for n_estimator in n_estimators: 
        print(n_estimator)
        clf.n_estimators = n_estimator
        clf.fit(X_train, y_train, copy.deepcopy(y_train)*4 + 1)
        train_err.append(1 - clf.score(X_train, y_train))
        test_err.append(1 - clf.score(X_test, y_test))
        
        Y_train_pred_prob=clf.predict_proba(X_train)[:,1]
        train_auc.append(AUC_score(y_train,Y_train_pred_prob))
        
        Y_test_pred_prob=clf.predict_proba(X_test)[:,1]
        test_auc.append(AUC_score(y_test,Y_test_pred_prob))
        
    return train_err, test_err, train_auc, test_auc

# %%
X_train,X_test,Y_train=data_processed()
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, train_size=0.80, random_state=42)

# %%
sum(Y_train) / len(Y_train)
# Out:
# 0.15286438529784538

# %%
sum(Y_val) / len(Y_val)
# Out:
# 0.1546768060836502

# %% [markdown]
# # Sweep min leaf samples

# %%
# Seed the random number generator:
np.random.seed(1)

n_estimators = 100
clf = LGBMClassifier(n_estimators = n_estimators)

min_samples_leaf = np.arange(2, 80, 10)

train_err, test_err, train_auc, test_auc = eval_tree_based_model_min_samples(clf, min_samples_leaf, X_train, 
                                                        Y_train, X_val, Y_val)

# %%
# Plot testing vs train error
plt.figure()
plt.plot(min_samples_leaf, test_err, label='Testing error')
plt.plot(min_samples_leaf, train_err, label='Training error')
plt.xlabel('Minimum Node Size')
plt.ylabel('Classification error')
plt.title('Random Forest with Gini Impurity and Minimum Node Size')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test error minimized at min_samples_leaf = %i' % min_samples_leaf[np.argmin(test_err)])

# %%
# Plot AUC
plt.figure()
plt.plot(min_samples_leaf, test_auc, label='Testing AUC')
plt.plot(min_samples_leaf, train_auc, label='Training AUC')
plt.xlabel('Minimum Node Size')
plt.ylabel('AUC')
plt.title('Random Forest with Gini Impurity and Minimum Node Size')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test auc maximized at min_samples_leaf = %i' % min_samples_leaf[np.argmax(test_auc)])
print('max auc:', np.max(test_auc))

# %% [markdown]
# ## Max depth regularization

# %%
np.random.seed(1)

n_estimators = 100
clf = LGBMClassifier(n_estimators = n_estimators)

max_depth = np.arange(10, 40, 3)

train_err, test_err, train_auc, test_auc = eval_tree_based_model_max_depth(clf, max_depth, X_train, 
                                                        Y_train, X_val, Y_val)

# %%
# Plot testing vs train error
plt.figure()
plt.plot(max_depth, test_err, label='Testing error')
plt.plot(max_depth, train_err, label='Training error')
plt.xlabel('Max Tree Depth')
plt.ylabel('Classification error')
plt.title('Random Forest with Gini Impurity and Max Tree Depth')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test error minimized at max_tree_depth = %i' % max_depth[np.argmin(test_err)])

# %%
# Plot AUC
plt.figure()
plt.plot(max_depth, test_auc, label='Testing AUC')
plt.plot(max_depth, train_auc, label='Training AUC')
plt.xlabel('Max Tree Depth')
plt.ylabel('AUC')
plt.title('Random Forest with Gini Impurity and Max Tree Depth')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test auc maximized at max_tree_depth = %i' % max_depth[np.argmax(test_auc)])
print('max auc:', np.max(test_auc))

# %% [markdown]
# ## Performance across # estimators

# %%
np.random.seed(1)

clf = LGBMClassifier()

n_estimators = np.arange(20, 300, 25)

train_err, test_err, train_auc, test_auc = eval_tree_based_model_n_estimators(clf, n_estimators, X_train, 
                                                        Y_train, X_val, Y_val)

# %%
# Plot testing vs train error
plt.figure()
plt.plot(n_estimators, test_err, label='Testing error')
plt.plot(n_estimators, train_err, label='Training error')
plt.xlabel('num estimators')
plt.ylabel('Classification error')
plt.title('Random Forest with Gini Impurity and Different n_estimators')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test error minimized at n_estimators = %i' % n_estimators[np.argmin(test_err)])

# %%
# Plot AUC
plt.figure()
plt.plot(n_estimators, test_auc, label='Testing AUC')
plt.plot(n_estimators, train_auc, label='Training AUC')
plt.xlabel('num estimators')
plt.ylabel('AUC')
plt.title('Random Forest with Gini Impurity and Different n_estimators')
plt.legend(loc=0, shadow=True, fontsize='x-large')
plt.show()

print('Test auc maximized at n_estimators = %i' % n_estimators[np.argmax(test_auc)])
print('max auc:', np.max(test_auc))

# %% [markdown]
# ## Grid search

# %%
parameters = {'n_estimators': np.arange(80, 121, 20), 'min_child_samples': np.arange(50, 80, 5), 'max_depth':  np.arange(5, 20, 3)}
rfc = LGBMClassifier(class_weight='balanced')
clf = GridSearchCV(rfc, parameters, scoring='roc_auc', verbose=2.1, n_jobs=1)
clf.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV] max_depth=5, min_child_samples=50, n_estimators=80 ..............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=5, min_child_samples=50, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=80 ..............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  max_depth=5, min_child_samples=50, n_estimators=80, score=0.696, total=   0.7s
# [CV] max_depth=5, min_child_samples=50, n_estimators=80 ..............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV]  max_depth=5, min_child_samples=50, n_estimators=80, score=0.693, total=   0.7s
# [CV] max_depth=5, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=80, score=0.688, total=   0.7s
# [CV] max_depth=5, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=80, score=0.692, total=   0.7s
# [CV] max_depth=5, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=100, score=0.689, total=   1.0s
# [CV] max_depth=5, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=100, score=0.697, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=100, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=100, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=100, score=0.692, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=120, score=0.689, total=   0.9s
# [CV] max_depth=5, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=5, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=120, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=120, score=0.688, total=   0.8s
# [CV] max_depth=5, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=50, n_estimators=120, score=0.692, total=   0.9s
# [CV] max_depth=5, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=80, score=0.697, total=   0.7s
# [CV] max_depth=5, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=80, score=0.687, total=   0.7s
# [CV] max_depth=5, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=100, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=100, score=0.698, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=100, score=0.694, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=100, score=0.688, total=   1.0s
# [CV] max_depth=5, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=5, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=120, score=0.689, total=   0.9s
# [CV] max_depth=5, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=120, score=0.698, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=120, score=0.694, total=   0.8s
# [CV] max_depth=5, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=120, score=0.688, total=   0.9s
# [CV] max_depth=5, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=55, n_estimators=120, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=80, score=0.688, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=5, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=80, score=0.692, total=   1.0s
# [CV] max_depth=5, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=100, score=0.689, total=   0.9s
# [CV] max_depth=5, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=100, score=0.697, total=   0.9s
# [CV] max_depth=5, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=5, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=100, score=0.687, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=100, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=120, score=0.690, total=   1.0s
# [CV] max_depth=5, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=120, score=0.697, total=   0.8s
# [CV] max_depth=5, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=120, score=0.694, total=   1.2s
# [CV] max_depth=5, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=120, score=0.687, total=   1.0s
# [CV] max_depth=5, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=60, n_estimators=120, score=0.693, total=   1.1s
# [CV] max_depth=5, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=80, score=0.689, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=80, score=0.696, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=80, score=0.688, total=   0.8s
# [CV] max_depth=5, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=5, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=100, score=0.690, total=   1.0s
# [CV] max_depth=5, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=100, score=0.697, total=   1.1s
# [CV] max_depth=5, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=100, score=0.688, total=   1.0s
# [CV] max_depth=5, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=100, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=120, score=0.690, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=120, score=0.688, total=   0.9s
# [CV] max_depth=5, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=65, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=5, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=80, score=0.688, total=   1.3s
# [CV] max_depth=5, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=80, score=0.698, total=   0.8s
# [CV] max_depth=5, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=5, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=5, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=100, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=100, score=0.697, total=   0.9s
# [CV] max_depth=5, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=100, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=100, score=0.688, total=   1.1s
# [CV] max_depth=5, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=100, score=0.693, total=   0.8s
# [CV] max_depth=5, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=120, score=0.689, total=   1.0s
# [CV] max_depth=5, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=120, score=0.697, total=   1.5s
# [CV] max_depth=5, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=5, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=120, score=0.688, total=   1.1s
# [CV] max_depth=5, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=70, n_estimators=120, score=0.693, total=   1.1s
# [CV] max_depth=5, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=80, score=0.696, total=   0.9s
# [CV] max_depth=5, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=5, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=80, score=0.687, total=   0.8s
# [CV] max_depth=5, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=80, score=0.692, total=   1.0s
# [CV] max_depth=5, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=100, score=0.689, total=   0.8s
# [CV] max_depth=5, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=100, score=0.697, total=   0.8s
# [CV] max_depth=5, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=100, score=0.694, total=   1.0s
# [CV] max_depth=5, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=100, score=0.688, total=   0.8s
# [CV] max_depth=5, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=5, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=120, score=0.689, total=   0.9s
# [CV] max_depth=5, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=120, score=0.697, total=   1.0s
# [CV] max_depth=5, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=5, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=120, score=0.688, total=   1.0s
# [CV] max_depth=5, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=5, min_child_samples=75, n_estimators=120, score=0.693, total=   0.9s
# [CV] max_depth=8, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=80, score=0.688, total=   1.0s
# [CV] max_depth=8, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=8, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=80, score=0.694, total=   1.0s
# [CV] max_depth=8, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=80, score=0.687, total=   1.0s
# [CV] max_depth=8, min_child_samples=50, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=100, score=0.689, total=   1.1s
# [CV] max_depth=8, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=100, score=0.697, total=   0.9s
# [CV] max_depth=8, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=100, score=0.694, total=   0.8s
# [CV] max_depth=8, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=100, score=0.687, total=   1.1s
# [CV] max_depth=8, min_child_samples=50, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=120, score=0.689, total=   1.0s
# [CV] max_depth=8, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=8, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=120, score=0.694, total=   0.8s
# [CV] max_depth=8, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=120, score=0.686, total=   1.0s
# [CV] max_depth=8, min_child_samples=50, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=50, n_estimators=120, score=0.692, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=8, min_child_samples=55, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=100, score=0.688, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=100, score=0.697, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=100, score=0.694, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=100, score=0.687, total=   0.8s
# [CV] max_depth=8, min_child_samples=55, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=120, score=0.688, total=   1.0s
# [CV] max_depth=8, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=8, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=120, score=0.694, total=   1.1s
# [CV] max_depth=8, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=120, score=0.687, total=   0.9s
# [CV] max_depth=8, min_child_samples=55, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=55, n_estimators=120, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=80, score=0.689, total=   1.0s
# [CV] max_depth=8, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=80, score=0.699, total=   1.0s
# [CV] max_depth=8, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=8, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=80, score=0.687, total=   1.1s
# [CV] max_depth=8, min_child_samples=60, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=8, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=100, score=0.689, total=   1.1s
# [CV] max_depth=8, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=100, score=0.699, total=   1.1s
# [CV] max_depth=8, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=100, score=0.693, total=   1.0s
# [CV] max_depth=8, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=100, score=0.688, total=   1.0s
# [CV] max_depth=8, min_child_samples=60, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=100, score=0.692, total=   1.0s
# [CV] max_depth=8, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=120, score=0.689, total=   1.5s
# [CV] max_depth=8, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=120, score=0.699, total=   1.5s
# [CV] max_depth=8, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=120, score=0.693, total=   1.4s
# [CV] max_depth=8, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=120, score=0.687, total=   1.1s
# [CV] max_depth=8, min_child_samples=60, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=60, n_estimators=120, score=0.692, total=   1.0s
# [CV] max_depth=8, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=8, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=80, score=0.698, total=   1.1s
# [CV] max_depth=8, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=80, score=0.693, total=   1.1s
# [CV] max_depth=8, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=80, score=0.688, total=   1.0s
# [CV] max_depth=8, min_child_samples=65, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=100, score=0.690, total=   1.0s
# [CV] max_depth=8, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=100, score=0.698, total=   0.9s
# [CV] max_depth=8, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=100, score=0.694, total=   1.3s
# [CV] max_depth=8, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=100, score=0.688, total=   1.4s
# [CV] max_depth=8, min_child_samples=65, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=100, score=0.691, total=   1.6s
# [CV] max_depth=8, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=120, score=0.689, total=   1.5s
# [CV] max_depth=8, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=120, score=0.697, total=   1.5s
# [CV] max_depth=8, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=120, score=0.693, total=   1.4s
# [CV] max_depth=8, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=120, score=0.687, total=   1.5s
# [CV] max_depth=8, min_child_samples=65, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=65, n_estimators=120, score=0.691, total=   1.5s
# [CV] max_depth=8, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=80, score=0.689, total=   1.0s
# [CV] max_depth=8, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=80, score=0.698, total=   1.1s
# [CV] max_depth=8, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=80, score=0.693, total=   1.0s
# [CV] max_depth=8, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=8, min_child_samples=70, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=8, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=100, score=0.689, total=   0.9s
# [CV] max_depth=8, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=100, score=0.697, total=   0.8s
# [CV] max_depth=8, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=100, score=0.693, total=   1.0s
# [CV] max_depth=8, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=100, score=0.687, total=   0.9s
# [CV] max_depth=8, min_child_samples=70, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=120, score=0.689, total=   1.1s
# [CV] max_depth=8, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=120, score=0.697, total=   1.0s
# [CV] max_depth=8, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=8, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=120, score=0.688, total=   0.9s
# [CV] max_depth=8, min_child_samples=70, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=70, n_estimators=120, score=0.692, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=80, score=0.690, total=   1.0s
# [CV] max_depth=8, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=80, score=0.698, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=8, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=80, score=0.686, total=   0.8s
# [CV] max_depth=8, min_child_samples=75, n_estimators=80 ..............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=80, score=0.691, total=   0.8s
# [CV] max_depth=8, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=100, score=0.690, total=   0.8s
# [CV] max_depth=8, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=100, score=0.698, total=   1.1s
# [CV] max_depth=8, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=100, score=0.687, total=   0.8s
# [CV] max_depth=8, min_child_samples=75, n_estimators=100 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=100, score=0.691, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=120, score=0.690, total=   1.0s
# [CV] max_depth=8, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=120, score=0.697, total=   1.2s
# [CV] max_depth=8, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=120, score=0.686, total=   0.9s
# [CV] max_depth=8, min_child_samples=75, n_estimators=120 .............
# [CV]  max_depth=8, min_child_samples=75, n_estimators=120, score=0.691, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=11, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=80, score=0.698, total=   0.8s
# [CV] max_depth=11, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=80, score=0.694, total=   1.2s
# [CV] max_depth=11, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=80, score=0.688, total=   1.0s
# [CV] max_depth=11, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=80, score=0.691, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=100, score=0.689, total=   1.2s
# [CV] max_depth=11, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=100, score=0.698, total=   1.0s
# [CV] max_depth=11, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=100, score=0.688, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=100, score=0.691, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=120, score=0.689, total=   1.1s
# [CV] max_depth=11, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=11, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=120, score=0.694, total=   1.0s
# [CV] max_depth=11, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=120, score=0.688, total=   1.0s
# [CV] max_depth=11, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=50, n_estimators=120, score=0.691, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=11, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=80, score=0.696, total=   0.9s
# [CV] max_depth=11, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=80, score=0.692, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=80, score=0.688, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=80, score=0.691, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=100, score=0.689, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=100, score=0.697, total=   1.1s
# [CV] max_depth=11, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=100, score=0.692, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=100, score=0.687, total=   0.9s
# [CV] max_depth=11, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=11, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=120, score=0.689, total=   0.9s
# [CV] max_depth=11, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=120, score=0.696, total=   0.9s
# [CV] max_depth=11, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=120, score=0.692, total=   1.1s
# [CV] max_depth=11, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=120, score=0.688, total=   1.0s
# [CV] max_depth=11, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=55, n_estimators=120, score=0.691, total=   0.9s
# [CV] max_depth=11, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=80, score=0.690, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=80, score=0.698, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=80, score=0.687, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=80, score=0.691, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=11, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=100, score=0.698, total=   0.9s
# [CV] max_depth=11, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=100, score=0.693, total=   0.9s
# [CV] max_depth=11, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=100, score=0.687, total=   1.0s
# [CV] max_depth=11, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=100, score=0.691, total=   0.8s
# [CV] max_depth=11, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=120, score=0.690, total=   1.0s
# [CV] max_depth=11, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=120, score=0.698, total=   1.0s
# [CV] max_depth=11, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=120, score=0.693, total=   1.1s
# [CV] max_depth=11, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=120, score=0.687, total=   1.2s
# [CV] max_depth=11, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=60, n_estimators=120, score=0.691, total=   0.9s
# [CV] max_depth=11, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=11, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=80, score=0.698, total=   0.9s
# [CV] max_depth=11, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=11, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=80, score=0.688, total=   0.9s
# [CV] max_depth=11, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=11, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=100, score=0.689, total=   1.4s
# [CV] max_depth=11, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=100, score=0.697, total=   1.1s
# [CV] max_depth=11, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=100, score=0.693, total=   0.9s
# [CV] max_depth=11, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=100, score=0.688, total=   1.2s
# [CV] max_depth=11, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=100, score=0.692, total=   1.2s
# [CV] max_depth=11, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=120, score=0.690, total=   1.1s
# [CV] max_depth=11, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=120, score=0.697, total=   1.0s
# [CV] max_depth=11, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=120, score=0.692, total=   0.9s
# [CV] max_depth=11, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=120, score=0.687, total=   1.1s
# [CV] max_depth=11, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=65, n_estimators=120, score=0.692, total=   1.0s
# [CV] max_depth=11, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=11, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=11, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=80, score=0.687, total=   1.0s
# [CV] max_depth=11, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=100, score=0.697, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=100, score=0.693, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=100, score=0.687, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=100, score=0.692, total=   1.0s
# [CV] max_depth=11, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=120, score=0.690, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=11, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=11, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=120, score=0.687, total=   1.0s
# [CV] max_depth=11, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=70, n_estimators=120, score=0.692, total=   1.1s
# [CV] max_depth=11, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=80, score=0.690, total=   0.8s
# [CV] max_depth=11, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=80, score=0.698, total=   0.9s
# [CV] max_depth=11, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=11, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=11, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=80, score=0.693, total=   2.2s
# [CV] max_depth=11, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=100, score=0.690, total=   1.0s
# [CV] max_depth=11, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=100, score=0.698, total=   0.9s
# [CV] max_depth=11, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=11, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=100, score=0.687, total=   1.1s
# [CV] max_depth=11, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=100, score=0.693, total=   1.0s
# [CV] max_depth=11, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=120, score=0.689, total=   1.1s
# [CV] max_depth=11, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=120, score=0.697, total=   1.2s
# [CV] max_depth=11, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=11, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=120, score=0.686, total=   1.1s
# [CV] max_depth=11, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=11, min_child_samples=75, n_estimators=120, score=0.693, total=   1.1s
# [CV] max_depth=14, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=80, score=0.697, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=80, score=0.687, total=   1.1s
# [CV] max_depth=14, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=100, score=0.690, total=   1.1s
# [CV] max_depth=14, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=100, score=0.698, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=100, score=0.693, total=   1.1s
# [CV] max_depth=14, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=100, score=0.687, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=120, score=0.689, total=   1.0s
# [CV] max_depth=14, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=120, score=0.697, total=   1.0s
# [CV] max_depth=14, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=120, score=0.693, total=   1.1s
# [CV] max_depth=14, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=120, score=0.686, total=   1.0s
# [CV] max_depth=14, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=50, n_estimators=120, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=14, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=80, score=0.693, total=   0.9s
# [CV] max_depth=14, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=80, score=0.689, total=   1.1s
# [CV] max_depth=14, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=14, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=100, score=0.689, total=   0.9s
# [CV] max_depth=14, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=100, score=0.696, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=100, score=0.693, total=   1.1s
# [CV] max_depth=14, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=100, score=0.689, total=   1.1s
# [CV] max_depth=14, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=100, score=0.692, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=120, score=0.690, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=120, score=0.696, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=120, score=0.689, total=   1.0s
# [CV] max_depth=14, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=55, n_estimators=120, score=0.691, total=   1.0s
# [CV] max_depth=14, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=60, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=14, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=60, n_estimators=80, score=0.698, total=   0.9s
# [CV] max_depth=14, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=14, min_child_samples=60, n_estimators=80, score=0.693, total=   1.0s
# [CV] max_depth=14, min_child_samples=60, n_estimators=80 .............
# ...
# [CV]  max_depth=14, min_child_samples=75, n_estimators=100, score=0.699, total=   0.9s
# [CV] max_depth=14, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=100, score=0.695, total=   1.1s
# [CV] max_depth=14, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=100, score=0.687, total=   1.0s
# [CV] max_depth=14, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=100, score=0.693, total=   1.0s
# [CV] max_depth=14, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=120, score=0.691, total=   1.0s
# [CV] max_depth=14, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=120, score=0.698, total=   0.9s
# [CV] max_depth=14, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=120, score=0.694, total=   1.1s
# [CV] max_depth=14, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=120, score=0.687, total=   1.0s
# [CV] max_depth=14, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=14, min_child_samples=75, n_estimators=120, score=0.693, total=   1.0s
# [CV] max_depth=17, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=80, score=0.690, total=   0.8s
# [CV] max_depth=17, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=80, score=0.697, total=   1.0s
# [CV] max_depth=17, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=80, score=0.693, total=   1.1s
# [CV] max_depth=17, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=100, score=0.697, total=   0.8s
# [CV] max_depth=17, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=100, score=0.693, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=100, score=0.687, total=   1.1s
# [CV] max_depth=17, min_child_samples=50, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=100, score=0.690, total=   1.0s
# [CV] max_depth=17, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=120, score=0.690, total=   1.0s
# [CV] max_depth=17, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=120, score=0.693, total=   0.9s
# [CV] max_depth=17, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=120, score=0.687, total=   1.0s
# [CV] max_depth=17, min_child_samples=50, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=50, n_estimators=120, score=0.691, total=   1.0s
# [CV] max_depth=17, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=80, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=80, score=0.697, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=80, score=0.694, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=80, score=0.689, total=   1.0s
# [CV] max_depth=17, min_child_samples=55, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=80, score=0.692, total=   0.8s
# [CV] max_depth=17, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=100, score=0.697, total=   1.0s
# [CV] max_depth=17, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=100, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=100, score=0.689, total=   1.3s
# [CV] max_depth=17, min_child_samples=55, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=100, score=0.692, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=120, score=0.690, total=   1.1s
# [CV] max_depth=17, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=120, score=0.697, total=   1.0s
# [CV] max_depth=17, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=17, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=120, score=0.689, total=   1.1s
# [CV] max_depth=17, min_child_samples=55, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=55, n_estimators=120, score=0.692, total=   1.0s
# [CV] max_depth=17, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=80, score=0.690, total=   0.8s
# [CV] max_depth=17, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=17, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=80, score=0.693, total=   0.8s
# [CV] max_depth=17, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=80, score=0.687, total=   1.0s
# [CV] max_depth=17, min_child_samples=60, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=17, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=100, score=0.689, total=   1.0s
# [CV] max_depth=17, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=100, score=0.697, total=   1.1s
# [CV] max_depth=17, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=100, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=100, score=0.687, total=   1.2s
# [CV] max_depth=17, min_child_samples=60, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=100, score=0.691, total=   0.9s
# [CV] max_depth=17, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=120, score=0.689, total=   1.0s
# [CV] max_depth=17, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=120, score=0.697, total=   0.9s
# [CV] max_depth=17, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=120, score=0.694, total=   0.9s
# [CV] max_depth=17, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=120, score=0.687, total=   1.2s
# [CV] max_depth=17, min_child_samples=60, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=60, n_estimators=120, score=0.691, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=80, score=0.689, total=   0.8s
# [CV] max_depth=17, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=80, score=0.697, total=   0.8s
# [CV] max_depth=17, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=80, score=0.694, total=   0.8s
# [CV] max_depth=17, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=80, score=0.687, total=   0.8s
# [CV] max_depth=17, min_child_samples=65, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=80, score=0.692, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=100, score=0.697, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=100, score=0.694, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=100, score=0.687, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=100, score=0.692, total=   1.0s
# [CV] max_depth=17, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=120, score=0.689, total=   0.9s
# [CV] max_depth=17, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=120, score=0.696, total=   1.0s
# [CV] max_depth=17, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=120, score=0.694, total=   1.8s
# [CV] max_depth=17, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=120, score=0.687, total=   1.3s
# [CV] max_depth=17, min_child_samples=65, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=65, n_estimators=120, score=0.691, total=   1.4s
# [CV] max_depth=17, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=80, score=0.690, total=   1.0s
# [CV] max_depth=17, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=80, score=0.698, total=   1.3s
# [CV] max_depth=17, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=80, score=0.694, total=   1.3s
# [CV] max_depth=17, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=80, score=0.687, total=   1.3s
# [CV] max_depth=17, min_child_samples=70, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=80, score=0.693, total=   1.0s
# [CV] max_depth=17, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=100, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=100, score=0.698, total=   0.9s
# [CV] max_depth=17, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=100, score=0.695, total=   1.1s
# [CV] max_depth=17, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=100, score=0.687, total=   1.0s
# [CV] max_depth=17, min_child_samples=70, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=100, score=0.693, total=   1.0s
# [CV] max_depth=17, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=120, score=0.690, total=   0.9s
# [CV] max_depth=17, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=120, score=0.698, total=   1.0s
# [CV] max_depth=17, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=120, score=0.695, total=   1.1s
# [CV] max_depth=17, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=120, score=0.686, total=   1.3s
# [CV] max_depth=17, min_child_samples=70, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=70, n_estimators=120, score=0.693, total=   1.2s
# [CV] max_depth=17, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=80, score=0.689, total=   1.3s
# [CV] max_depth=17, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=80, score=0.698, total=   1.2s
# [CV] max_depth=17, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=80, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=80, score=0.687, total=   0.9s
# [CV] max_depth=17, min_child_samples=75, n_estimators=80 .............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=80, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=100, score=0.689, total=   0.9s
# [CV] max_depth=17, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=100, score=0.698, total=   1.1s
# [CV] max_depth=17, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=100, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=100, score=0.687, total=   1.1s
# [CV] max_depth=17, min_child_samples=75, n_estimators=100 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=100, score=0.694, total=   1.3s
# [CV] max_depth=17, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=120, score=0.690, total=   1.3s
# [CV] max_depth=17, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=120, score=0.698, total=   1.1s
# [CV] max_depth=17, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=120, score=0.694, total=   1.0s
# [CV] max_depth=17, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=120, score=0.687, total=   1.0s
# [CV] max_depth=17, min_child_samples=75, n_estimators=120 ............
# [CV]  max_depth=17, min_child_samples=75, n_estimators=120, score=0.693, total=   1.0s
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:  7.4min finished
# GridSearchCV(estimator=LGBMClassifier(class_weight='balanced'), n_jobs=1,
#              param_grid={'max_depth': array([ 5,  8, 11, 14, 17]),
#                          'min_child_samples': array([50, 55, 60, 65, 70, 75]),
#                          'n_estimators': array([ 80, 100, 120])},
#              scoring='roc_auc', verbose=2.1)

# %%
results_df = pd.DataFrame(clf.cv_results_)

# %%
clf.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_max_depth', 'param_min_child_samples', 'param_n_estimators', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
results_sub_df = results_df.loc[:, ['param_max_depth', 'param_min_child_samples', 'param_n_estimators', 'mean_test_score', 'std_test_score', 'rank_test_score']]

# %%
results_sub_df.sort_values('rank_test_score').head(20)
# Out:
#    param_max_depth param_min_child_samples param_n_estimators  \
# 70              14                      75                100
# 69              14                      75                 80
# 11               5                      65                120
# 71              14                      75                120
# 84              17                      70                 80
# 88              17                      75                100
# 68              14                      70                120
# 85              17                      70                100
# 66              14                      70                 80
# 67              14                      70                100
# 76              17                      55                100
# 8                5                      60                120
# 10               5                      65                100
# 87              17                      75                 80
# 89              17                      75                120
# 75              17                      55                 80
# 52              11                      75                100
# 86              17                      70                120
# 77              17                      55                120
# 7                5                      60                100
#
#     mean_test_score  std_test_score  rank_test_score
# 70         0.692769        0.003899                1
# 69         0.692724        0.003963                2
# 11         0.692652        0.003292                3
# 71         0.692597        0.003735                4
# 84         0.692518        0.003661                5
# 88         0.692510        0.003895                6
# 68         0.692486        0.003869                7
# 85         0.692470        0.003814                8
# 66         0.692432        0.003655                9
# 67         0.692429        0.003858               10
# 76         0.692405        0.002923               11
# 8          0.692404        0.003416               12
# 10         0.692401        0.003146               13
# 87         0.692368        0.003640               14
# 89         0.692368        0.003859               15
# 75         0.692309        0.003091               16
# 52         0.692281        0.003842               17
# 86         0.692280        0.003914               18
# 77         0.692267        0.002838               19
# 7          0.692255        0.003485               20

# %%
Y_val_pred_prob=clf.best_estimator_.predict_proba(X_val)[:,1]
AUC_score(Y_val,Y_val_pred_prob)
# Out:
# 0.6920981759176406

# %%
Y_train_pred_prob=clf.best_estimator_.predict_proba(X_train)[:,1]
AUC_score(Y_train,Y_train_pred_prob)
# Out:
# 0.7338615585766592

# %%
Y_val_pred=clf.best_estimator_.predict(X_val)
confusion_matrix(Y_val,Y_val_pred)
# Out:
# array([[21053, 12295],
#        [ 2165,  3937]])

# %%
Y_train_pred=clf.best_estimator_.predict(X_train)
confusion_matrix(Y_train,Y_train_pred)
# Out:
# array([[86083, 47595],
#        [ 7255, 16867]])

# %%
clf.best_estimator_.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': 'balanced',
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': 14,
#  'min_child_samples': 75,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': 'warn',
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %% [markdown]
# ## Output for submissions - evaluate on test set

# %%
Y_test_pred_prob=clf.best_estimator_.predict_proba(X_test)[:,1]

# %%
def to_submission(ids, y_test_predicted_probability):
    y_test=pd.DataFrame(y_test_predicted_probability,columns=['loan_status'], index=ids)
    y_test.index.name = 'id'
    y_test.to_csv('data/submission.csv')
    return

to_submission(pd.read_csv("data/2022-02-07_LOANS_TEST.csv")['id'].values, Y_test_pred_prob)
